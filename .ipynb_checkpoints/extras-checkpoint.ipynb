# %%
import pandas as pd
vf1 = pd.read_csv("/home/saphira/Desktop/datos/vf_Ene-nov.csv")
vf2 = pd.read_csv("/home/saphira/Desktop/datos/vf_dic.csv")
vf = pd.concat([vf1,vf2])
vf.index = range(vf.shape[0])
vf
# Out:
#        MES          MUNICIPIO HECHOS                              COLONIA  \
# 0        1         Cadereyta Jiménez                 VALLE DE LOS ENCINOS
# 1        1         Cadereyta Jiménez                      VALLE DEL ROBLE
# 2        1         Cadereyta Jiménez                      VALLE DEL ROBLE
# 3        1         Ciénega De Flores                     LOMAS DE CIENEGA
# 4        1         Ciénega De Flores                         REAL DEL SOL
# 5        1         Ciénega De Flores                     VILLAS DE ALCALA
# 6        1                 El Carmen                             EL JARAL
# 7        1                  Escobedo                         LAS MALVINAS
# 8        1                    García       AMPLIACION LOS NOGALES FOM 177
# 9        1                 Guadalupe                   CAMPESTRE LA SILLA
# 10       1                 Guadalupe                 FUENTES DE GUADALUPE
# 11       1                 Guadalupe                     DE LA GARZA MELO
# ...

# %%
vf.columns
# Out:
# Index(['MES', 'MUNICIPIO HECHOS', 'COLONIA', 'DELITO', 'MODALIDAD',
#        'FECHA HECHOS', 'VIOLENCIA', 'TIPO VIOLENCIA', 'CALLE', 'ENTRE CALLE',
#        'NUMERO EXTERIOR', 'NUMERO INTERIOR', 'HORA HECHOS', 'CARPETA',
#        'FECHA APERTURA', 'UNIDAD DE INVESTIGACION', 'ESPECIALIDAD', 'JEFATURA',
#        'REGION', 'TIPO LUGAR', 'TIPO ARMA', 'VICTIMA', 'SEXO',
#        'EDADES (VICTIMA)', 'PARENTESCO', 'ESTADO CIVIL', 'OCUPACION',
#        'ESCOLARIDAD', 'DIRECCION (VICTIMA)', 'RELIGION',
#        'ES LA PRIMERA AGRESION', 'DESDE CUANDO RECIBE AGRESIONES',
#        'ALGUIEN MAS RECIBIO AGRESIONES', 'RECIBIO ATENCION PSICOLOGICA',
#        'RECIBIO ATENCION MEDICA', 'AGRESOR', 'SEXO.1', 'EDADES (AGRESOR)',
#        'ESTADO CIVIL.1', 'OCUPACION.1', 'ESCOLARIDAD.1', 'DIRECCION (AGRESOR)',
#        'RELIGION.1', 'RECIBIO ATENCION PSICOLOGICA.1',
#        'TIPO Y GRAVEDAD DE LA AGRESION', 'INGRESO MENSUAL (FAMILIAR)',
#        'MOTIVO DE LA AGRESION'],
#       dtype='object')

# %%
vf = vf.drop(["COLONIA", "DELITO", "MODALIDAD", "VIOLENCIA", "TIPO VIOLENCIA", "CALLE", "ENTRE CALLE", \
              "NUMERO EXTERIOR", "NUMERO INTERIOR", "CARPETA", "FECHA APERTURA", "UNIDAD DE INVESTIGACION", \
              "ESPECIALIDAD", "JEFATURA", "REGION", "TIPO LUGAR", "TIPO ARMA", "DIRECCION (VICTIMA)", \
              "RELIGION", "ES LA PRIMERA AGRESION", "DESDE CUANDO RECIBE AGRESIONES", "ALGUIEN MAS RECIBIO AGRESIONES",\
              "RECIBIO ATENCION PSICOLOGICA", "RECIBIO ATENCION MEDICA", "DIRECCION (AGRESOR)", "RELIGION.1",\
              "RECIBIO ATENCION PSICOLOGICA.1", "TIPO Y GRAVEDAD DE LA AGRESION","INGRESO MENSUAL (FAMILIAR)",\
              "MOTIVO DE LA AGRESION"], axis = 1)
vf
# Out:
#        MES          MUNICIPIO HECHOS FECHA HECHOS HORA HECHOS  VICTIMA  SEXO  \
# 0        1         Cadereyta Jiménez   2018/01/01       23:40        1     F
# 1        1         Cadereyta Jiménez   2017/12/27       08:00        1     F
# 2        1         Cadereyta Jiménez   2018/01/01       11:00        1     F
# 3        1         Ciénega De Flores   2017/12/22       11:00        1     F
# 4        1         Ciénega De Flores   2017/12/25       19:00        1     F
# 5        1         Ciénega De Flores   2017/12/25       19:30        1     F
# 6        1                 El Carmen   2017/12/31       13:30        1     F
# 7        1                  Escobedo   2018/01/01       02:30        1     F
# 8        1                    García   2018/01/01       10:20        1     F
# 9        1                 Guadalupe   2017/12/30       06:00        1     F
# 10       1                 Guadalupe   2018/01/01       21:00        1     F
# ...

# %%
cols = ['mes', 'mpio', 'fecha', 'hora', 'victima', 'sexo_v','edad_v','parentesco','edo_civil_v',\
        'ocupacion_v','escolaridad_v','agresor', 'sexo_a','edad_a','edo_civil_a','ocupacion_a','escolaridad_a']
vf.columns = cols
vf
# Out:
#        mes                      mpio       fecha   hora  victima sexo_v  \
# 0        1         Cadereyta Jiménez  2018/01/01  23:40        1      F
# 1        1         Cadereyta Jiménez  2017/12/27  08:00        1      F
# 2        1         Cadereyta Jiménez  2018/01/01  11:00        1      F
# 3        1         Ciénega De Flores  2017/12/22  11:00        1      F
# 4        1         Ciénega De Flores  2017/12/25  19:00        1      F
# 5        1         Ciénega De Flores  2017/12/25  19:30        1      F
# 6        1                 El Carmen  2017/12/31  13:30        1      F
# 7        1                  Escobedo  2018/01/01  02:30        1      F
# 8        1                    García  2018/01/01  10:20        1      F
# 9        1                 Guadalupe  2017/12/30  06:00        1      F
# 10       1                 Guadalupe  2018/01/01  21:00        1      F
# 11       1                 Guadalupe  2018/01/01  08:40        1      F
# ...

# %%
print(vf.mpio.unique())
# Out:
# ['Cadereyta Jiménez' 'Ciénega De Flores' 'El Carmen' 'Escobedo' 'García'
#  'Guadalupe' 'Juárez' 'Monterrey' 'Salinas Victoria'
#  'San Nicolás De Los Garza' 'Apodaca' 'Linares' 'Montemorelos'
#  'Sabinas Hidalgo' 'San Pedro Garza García' 'Santa Catarina' 'Santiago'
#  'Allende' 'Zuazua' 'Doctor Arroyo' 'Pesquería' 'Galeana' 'Marín' 'Mina'
#  'Anahuac' 'Higueras' 'Bravo' 'China' 'Bustamante' 'Lampazos' 'Terán'
#  'Aramberri' 'Cerralvo' 'Zaragoza' 'Hidalgo' 'Anáhuac' 'Agualeguas'
#  'Hualahuises' 'Ramones' 'Villaldama' 'Iturbide' 'Melchor Ocampo' 'Parás'
#  'Mier Y Noriega' 'Herreras' 'Abasolo' 'Doctor González' 'Doctor Coss'
#  'Treviño' 'Vallecillo' 'Aldamas']

# %%
vf.loc[:,"pob"] = mpios = [2639 if v == "Abasolo" else 2439 if v == "Agualeguas" else 1292 if v == "Aldamas"
             else 34353 if v=="Allende" else 18194 if (v=="Anahuac" or v=="Anáhuac") 
             else 597207 if v=="Apodaca" else 16152 if v=="Aramberri" else 3977 if v=="Bustamante"
              else 95534 if v=="Cadereyta Jiménez" else 38306 if v=="El Carmen" else 7757 if v=="Cerralvo"
             else 42715 if v=="Ciénega De Flores" else 10835 if v== 'China' else 34110 if v == 'Doctor Arroyo'
              else 1632 if v=='Doctor Coss' else 2861 if v=='Doctor González' else 41130 if v=='Galeana'
              else 247370 if v=='García' else 123156 if v=="San Pedro Garza García" else 5479 if v=="Bravo"
              else 425148 if v=='Escobedo' else 14795 if v=='Terán' else 1044 if v=='Treviño'
              else 6011 if v=='Zaragoza' else 67294 if v=='Zuazua' else 682880 if v=='Guadalupe'
              else 1764 if v=='Herreras' else 1511 if v=='Higueras' else 6921 if v=='Hualahuises'
              else 3571 if v=='Iturbide' else 333481 if v=='Juárez' else 5238 if v=='Lampazos'
              else 79853 if v=='Linares' else 5630 if v=='Marín' else 955 if v=='Melchor Ocampo'
              else 6996 if v=='Mier Y Noriega' else 5326 if v=='Mina' else 60829 if v=='Montemorelos'
              else 1109171 if v=='Monterrey' else 971 if v=='Parás' else 87168 if v=='Pesquería'
              else 4469 if v=='Ramones' else 2640 if v=="Rayones" else 35456 if v=='Sabinas Hidalgo'
              else 54192 if v=='Salinas Victoria' else 430143 if v=='San Nicolás De Los Garza'
              else 13836 if v=="Hidalgo" else 296954 if v=='Santa Catarina' else 42407 if v=='Santiago'
              else 1632 if v=="Vallecillo" else 4080 if v=="Villaldama" else "NA" for v in vf.mpio]
# Out:
#        mes                      mpio       fecha   hora  victima sexo_v  \
# 0        1         Cadereyta Jiménez  2018/01/01  23:40        1      F
# 1        1         Cadereyta Jiménez  2017/12/27  08:00        1      F
# 2        1         Cadereyta Jiménez  2018/01/01  11:00        1      F
# 3        1         Ciénega De Flores  2017/12/22  11:00        1      F
# 4        1         Ciénega De Flores  2017/12/25  19:00        1      F
# 5        1         Ciénega De Flores  2017/12/25  19:30        1      F
# 6        1                 El Carmen  2017/12/31  13:30        1      F
# 7        1                  Escobedo  2018/01/01  02:30        1      F
# 8        1                    García  2018/01/01  10:20        1      F
# 9        1                 Guadalupe  2017/12/30  06:00        1      F
# 10       1                 Guadalupe  2018/01/01  21:00        1      F
# 11       1                 Guadalupe  2018/01/01  08:40        1      F
# ...

# %%
mpios = [1 if v == "Abasolo" else 2 if v == "Agualeguas" else 3 if v == "Aldamas"
             else 4 if v=="Allende" else 5 if (v=="Anahuac" or v=="Anáhuac") 
             else 6 if v=="Apodaca" else 7 if v=="Aramberri" else 8 if v=="Bustamante"
              else 9 if v=="Cadereyta Jiménez" else 10 if v=="El Carmen" else 11 if v=="Cerralvo"
             else 12 if v=="Ciénega De Flores" else 13 if v== 'China' else 14 if v == 'Doctor Arroyo'
              else 15 if v=='Doctor Coss' else 16 if v=='Doctor González' else 17 if v=='Galeana'
              else 18 if v=='García' else 19 if v=="San Pedro Garza García" else 20 if v=="Bravo"
              else 21 if v=='Escobedo' else 22 if v=='Terán' else 23 if v=='Treviño'
              else 24 if v=='Zaragoza' else 25 if v=='Zuazua' else 26 if v=='Guadalupe'
              else 27 if v=='Herreras' else 28 if v=='Higueras' else 29 if v=='Hualahuises'
              else 30 if v=='Iturbide' else 31 if v=='Juárez' else 32 if v=='Lampazos'
              else 33 if v=='Linares' else 34 if v=='Marín' else 35 if v=='Melchor Ocampo'
              else 36 if v=='Mier Y Noriega' else 37 if v=='Mina' else 38 if v=='Montemorelos'
              else 39 if v=='Monterrey' else 40 if v=='Parás' else 41 if v=='Pesquería'
              else 42 if v=='Ramones' else 43 if v=="Rayones" else 44 if v=='Sabinas Hidalgo'
              else 45 if v=='Salinas Victoria' else 46 if v=='San Nicolás De Los Garza'
              else 47 if v=="Hidalgo" else 48 if v=='Santa Catarina' else 49 if v=='Santiago'
              else 50 if v=="Vallecillo" else 51 if v=="Villaldama" else "NA" for v in vf.mpio]

# %%
vf.mpio = mpios
vf
# Out:
#        mes  mpio       fecha   hora  victima sexo_v  edad_v     parentesco  \
# 0        1     9  2018/01/01  23:40        1      F      46    UNION LIBRE
# 1        1     9  2017/12/27  08:00        1      F      26  CONCUBINO (A)
# 2        1     9  2018/01/01  11:00        1      F      42        NINGUNO
# 3        1    12  2017/12/22  11:00        1      F      26  CONCUBINO (A)
# 4        1    12  2017/12/25  19:00        1      F      38     ESPOSO (A)
# 5        1    12  2017/12/25  19:30        1      F      28  CONCUBINO (A)
# 6        1    10  2017/12/31  13:30        1      F      28  CONCUBINO (A)
# 7        1    21  2018/01/01  02:30        1      F      61     ESPOSO (A)
# 8        1    18  2018/01/01  10:20        1      F      54      ABUELO(A)
# 9        1    26  2017/12/30  06:00        1      F      39     ESPOSO (A)
# 10       1    26  2018/01/01  21:00        1      F      19          PADRE
# ...

# %%
vf.loc[:,"pob"] = mpios = [2639 if v == "Abasolo" else 2439 if v == "Agualeguas" else 1292 if v == "Aldamas"
             else 34353 if v=="Allende" else 18194 if (v=="Anahuac" or v=="Anáhuac") 
             else 597207 if v=="Apodaca" else 16152 if v=="Aramberri" else 3977 if v=="Bustamante"
              else 95534 if v=="Cadereyta Jiménez" else 38306 if v=="El Carmen" else 7757 if v=="Cerralvo"
             else 42715 if v=="Ciénega De Flores" else 10835 if v== 'China' else 34110 if v == 'Doctor Arroyo'
              else 1632 if v=='Doctor Coss' else 2861 if v=='Doctor González' else 41130 if v=='Galeana'
              else 247370 if v=='García' else 123156 if v=="San Pedro Garza García" else 5479 if v=="Bravo"
              else 425148 if v=='Escobedo' else 14795 if v=='Terán' else 1044 if v=='Treviño'
              else 6011 if v=='Zaragoza' else 67294 if v=='Zuazua' else 682880 if v=='Guadalupe'
              else 1764 if v=='Herreras' else 1511 if v=='Higueras' else 6921 if v=='Hualahuises'
              else 3571 if v=='Iturbide' else 333481 if v=='Juárez' else 5238 if v=='Lampazos'
              else 79853 if v=='Linares' else 5630 if v=='Marín' else 955 if v=='Melchor Ocampo'
              else 6996 if v=='Mier Y Noriega' else 5326 if v=='Mina' else 60829 if v=='Montemorelos'
              else 1109171 if v=='Monterrey' else 971 if v=='Parás' else 87168 if v=='Pesquería'
              else 4469 if v=='Ramones' else 2640 if v=="Rayones" else 35456 if v=='Sabinas Hidalgo'
              else 54192 if v=='Salinas Victoria' else 430143 if v=='San Nicolás De Los Garza'
              else 13836 if v=="Hidalgo" else 296954 if v=='Santa Catarina' else 42407 if v=='Santiago'
              else 1632 if v=="Vallecillo" else 4080 if v=="Villaldama" else "NA" for v in vf.mpio]
# Out:
#        mes  mpio       fecha   hora  victima sexo_v  edad_v     parentesco  \
# 0        1     9  2018/01/01  23:40        1      F      46    UNION LIBRE
# 1        1     9  2017/12/27  08:00        1      F      26  CONCUBINO (A)
# 2        1     9  2018/01/01  11:00        1      F      42        NINGUNO
# 3        1    12  2017/12/22  11:00        1      F      26  CONCUBINO (A)
# 4        1    12  2017/12/25  19:00        1      F      38     ESPOSO (A)
# 5        1    12  2017/12/25  19:30        1      F      28  CONCUBINO (A)
# 6        1    10  2017/12/31  13:30        1      F      28  CONCUBINO (A)
# 7        1    21  2018/01/01  02:30        1      F      61     ESPOSO (A)
# 8        1    18  2018/01/01  10:20        1      F      54      ABUELO(A)
# 9        1    26  2017/12/30  06:00        1      F      39     ESPOSO (A)
# 10       1    26  2018/01/01  21:00        1      F      19          PADRE
# ...

# %%
import pandas as pd
vf = pd.read_csv("vf_datos.csv")
vf
import matplotlib.pyplot as plt
import numpy as np

#ax = vf.hora.plot.bar(x='lab', y='val', rot=0)

# %%
vf.to_csv('vf_datos.csv', header=True, index=False)
